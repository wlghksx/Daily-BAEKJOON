# %% [markdown]
# <a href="https://colab.research.google.com/github/wlghksx/Daily-BAEKJOON/blob/main/%EB%B0%B1%EC%A4%80%EB%8B%A8%EA%B3%84%EB%B3%84_%EB%B8%8C%EB%A3%A8%ED%8A%B8%ED%8F%AC%EC%8A%A4_1436.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1436번 영화감독 숌

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = int(input())
a = 666
count = 0

while True : 
  if '666' in str(a):
    count +=1
    if count == n :
      print(a)
      break
  a = a+1
# Out:
# 2
# 1666
